# %%
import numpy as np
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv('gene_oneHotEncoding.csv', )
lineage = pd.read_csv('lineages.csv',sep='\t', index_col = 0)

# %%
X = X.set_index('Unnamed: 0')
X
# Out:
#             group_1034  cysNC  group_1277  group_1352  group_1405  group_1784  \
# Unnamed: 0
# 2855                 0      1           1           1           1           1
# 13685                0      1           1           1           1           1
# 27228                0      0           1           1           1           1
# 31457                0      1           1           1           1           1
# 31458                0      1           1           1           1           1
# ...                ...    ...         ...         ...         ...         ...
# 61379                0      1           1           1           1           1
# 61380                0      1           1           1           1           1
# 61381                0      1           1           1           1           1
# 61382                0      1           1           1           1           1
# 61383                0      1           1           1           1           1
#
# ...

# %%
lineage = lineage.set_index(X.index)

# %%
train, test = train_test_split(X, test_size = 0.2)
train.head()
# Out:
#             group_1034  cysNC  group_1277  group_1352  group_1405  group_1784  \
# Unnamed: 0
# 31508                0      1           1           1           1           1
# 31587                0      1           1           1           1           1
# 31708                0      1           1           1           1           1
# 31711                0      1           1           1           1           1
# 31588                0      1           1           1           1           1
#
#             group_2013  group_2063  folP  group_340  ...  group_3840  \
# Unnamed: 0                                           ...
# 31508                1           1     1          1  ...           0
# 31587                1           1     1          1  ...           0
# 31708                1           1     1          1  ...           0
# 31711                1           1     1          1  ...           0
# 31588                1           1     1          1  ...           0
#
# ...

# %%
X_train = train.iloc[:,:2452].to_numpy()
X_test = test.iloc[:,:2452].to_numpy()

# %%
y_train = train['lineage'].to_numpy()
y_test = test['lineage'].to_numpy()

# %%
#Train con variabili filtrate
ranked_data = pd.read_csv("geneRankedSVM.csv")
ranked_data = ranked_data.set_index('Unnamed: 0')
#ranked_f = ranked_data['0']

# %%
ranked_data
# Out:
#             group_2306  fimA  group_2456  group_2383  group_453  group_95  \
# Unnamed: 0
# 2855                 0     0           0           1          0         1
# 13685                0     1           0           0          0         1
# 27228                1     0           0           1          1         1
# 31457                0     0           0           1          0         1
# 31458                0     1           0           0          0         1
# ...                ...   ...         ...         ...        ...       ...
# 61379                0     0           0           0          0         1
# 61380                0     0           0           1          0         1
# 61381                0     1           1           0          0         0
# 61382                0     0           0           0          0         1
# 61383                0     1           1           0          0         1
#
# ...

# %%
#n = 120

data_f = ranked_data.join(lineage)

lineage = lineage.set_index(data_f.index)

# %%
trainf, testf = train_test_split(data_f, test_size = 0.1)
X_trainf = trainf.iloc[:,:-1].to_numpy()
X_testf = testf.iloc[:,:-1].to_numpy()
y_trainf = trainf['lineage'].to_numpy()
y_testf = testf['lineage'].to_numpy()

# %%
#SVM
from sklearn import svm
svm = svm.SVC(kernel='linear')
svm.fit(X_trainf, y_trainf)
y_predf = svm.predict(X_testf)
metrics.confusion_matrix(y_testf, y_predf)
# Out:
# array([[ 8,  3],
#        [ 0, 31]])

# %%
svm.score(X_testf, y_testf, sample_weight=None)
# Out:
# 0.9285714285714286

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score
Xf = data_f.iloc[:,:-1].to_numpy()
yf= data_f['lineage'].to_numpy()
scores = cross_val_score(svm, Xf, yf, cv=5)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.94 accuracy with a standard deviation of 0.03

# %%
lr.score(X_testf, y_testf, sample_weight=None)
# Out:
# 0.8452380952380952

# %%
data_f.iloc[:,:-1]
# Out:
#             group_2306  fimA  group_2456  group_2383  group_453  group_95  \
# Unnamed: 0
# 2855                 0     0           0           1          0         1
# 13685                0     1           0           0          0         1
# 27228                1     0           0           1          1         1
# 31457                0     0           0           1          0         1
# 31458                0     1           0           0          0         1
# ...                ...   ...         ...         ...        ...       ...
# 61379                0     0           0           0          0         1
# 61380                0     0           0           1          0         1
# 61381                0     1           1           0          0         0
# 61382                0     0           0           0          0         1
# 61383                0     1           1           0          0         1
#
# ...

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score
Xf = data_f.iloc[:,:-1].to_numpy()
yf= data_f['lineage'].to_numpy()
scores = cross_val_score(LogisticRegression(penalty ='l2'), Xf, yf, cv=5)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.88 accuracy with a standard deviation of 0.06

# %%
scores
# Out:
# array([0.82142857, 0.91666667, 0.9047619 , 0.94047619, 0.79518072])

# %%
#normalizzazione
from sklearn import preprocessing
X_trainf_normalized = preprocessing.normalize(Xf, norm='l2')
scores = cross_val_score(LogisticRegression(penalty ='l2'), X_trainf_normalized, yf, cv=7)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.73 accuracy with a standard deviation of 0.05

# %%
scores
# Out:
# array([0.71666667, 0.73333333, 0.7       , 0.75      , 0.85      ,
#        0.66666667, 0.71186441])

# %%
import mca

# %%
len(X.index)
# Out:
# 419

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_trainf, y_trainf)
y_predf = rf.predict(X_testf)

# %%
rf.score(X_testf, y_testf, sample_weight=None)
# Out:
# 0.8690476190476191

# %%
metrics.confusion_matrix(y_testf, y_predf)
# Out:
# array([[16, 10],
#        [ 1, 57]])

# %%
#Cross Validation
from sklearn.model_selection import cross_val_score
Xf = data_f.iloc[:,:-1].to_numpy()
yf = data_f['lineage'].to_numpy()
X_trainf_normalized = preprocessing.normalize(Xf, norm='l2')
scores = cross_val_score(RandomForestClassifier(), X_trainf_normalized, yf, cv=7)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.72 accuracy with a standard deviation of 0.07

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier

# %%
neigh = KNeighborsClassifier(n_neighbors=9)

# %%
neigh.fit(X_trainf, y_trainf)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_predf = neigh.predict(X_testf)
metrics.confusion_matrix(y_testf, y_predf)
# Out:
# array([[10, 16],
#        [ 0, 58]])

# %%
neigh.score(X_testf, y_testf, sample_weight=None)
# Out:
# 0.8095238095238095

# %%
#Cross Validation

X_trainf_normalized = preprocessing.normalize(Xf, norm='l2')
scores = cross_val_score(KNeighborsClassifier(n_neighbors=3), X_trainf_normalized, yf, cv=7)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.75 accuracy with a standard deviation of 0.10

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB().fit(X_trainf, y_trainf)
y_pred = gnb.predict(X_testf)

# %%
print("Number of mislabeled points out of a total %d points : %d"
  % (X_testf.shape[0], (y_testf != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 84 points : 18

# %%
metrics.confusion_matrix(y_testf, y_pred)
# Out:
# array([[10, 16],
#        [ 2, 56]])

# %%
gnb.score(X_testf, y_testf, sample_weight=None)
# Out:
# 0.7857142857142857
